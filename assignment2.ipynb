# %% [markdown]
# # Analytics employee attrition and perfomance
#
#
# ## I .Dataset description
#
# Uncover the factors that lead to employee attrition and explore important questions such as show me a breakdown of distance from home by job role and attrition or compare average monthly income by education and attrition . Test age, gender, affect attrition .
#
# #### 1.Age(number)
# #### 2.Attrition (category)
# + yes
# + no
# #### 3.BusinessTravel(category)
# + Non-Travel
# + Travel Rately
# + Travel Frequently
# #### 4.DailyRate(number)
# #### 5.Department(category)
# + Sale
# + Research&Development
# + Human Resources
# #### 6.DistanceFromHome(number)
# #### 7.Education(number from 1 to 4)
# #### 8.EducationField(category)
# + Life Sciences
# + Other
# + Medical
# + arketing
# + Technical Degree
# + man Resources
# #### 9.EmployeeCount (number same =1) .....
#
# ## II.Data

# %%
import pandas as pd
import numpy as np
import random
from scipy import stats
from scipy.stats import ttest_ind
Data=pd.read_csv("Data.csv")
print(Data)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                  1  ...                         1            80
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %% [markdown]
# ### Comment :
#
# + Data can be number or category
# + There are columns with one same value > not playing into with columns other

# %% [markdown]
# ## III. Handle missing value
# .....

# %% [markdown]
# ## IV. Analysis data

# %%
def number_or_category(Data_test):
    try:
        try_=Data_test+1
    except:
        Data_type="category"
    else:
        Data_type="number"
    return (Data_type)

# %%
# target have type là number and feature have type category
def Xuly_T_test(Data,feature,target,STT,HT):
    # Tính số thuộc tính trong feature example BusinessTravel have 3 tt là Non-Travel,Travel Rately and Travel Frequently
    feature_set=set(Data[feature]) # convert set{} to remove thuộc tính  same
    #print(feature_set)
    so_thuoc_tinh_feature=len(feature_set)
    #print(so_thuoc_tinh_feature)
    if so_thuoc_tinh_feature==1:
        print(STT," .",feature + " are not playing into current " + target + " Rate")
    else:
        # tách data của target theo từng thuộc tính trong feature
        sample=[]
        not_32=0
        for thuoc_tinh in feature_set:
            row=(Data[Data[feature]==thuoc_tinh].index)
            po_target=list(Data[target][row])
            try:
                take_32=random.sample(po_target,k=32)
            except:
                print(STT," .","Data of ",feature,"not enough 32 for one properties")
                not_32=1
                break
            else:
                sample.append(take_32)
        #print(sample)
        if len(sample) ==2 and not_32==0:
            f,p=stats.ttest_ind(sample[0],sample[1])
            if p< 0.05:
                if HT ==1:
                    print(STT," .",target + " are playing into current " + feature + " Rate" " :  ",(1-p)*100,"%")
                else: 
                    print(STT," .",feature + " are playing into current " + target + " Rate" " :  ",(1-p)*100,"%")
            else :
                if HT ==1:
                    print(STT," .",target + " are not playing into current " + feature + " Rate" " :  ",(1-p)*100,"%")
                else:
                    print(STT," .",feature + " are not playing into current " + target + " Rate" " :  ",(1-p)*100,"%")
        if len(sample) > 2 and not_32==0:# có nhiều hơn 2 thuộc tính xét các cặp nếu 1 cặp khác nhau thì khác nhau
            khac=0
            for i in range(len(sample)-1):
                f,p=stats. f_oneway(sample[i],sample[i+1])
                if p <0.05:
                    khac=1
                    break
            if khac==1:
                if HT ==1:
                    print(STT," .",target + " are playing into current " + feature + " Rate" " :  ",(1-p)*100,"%")
                else: 
                    print(STT," .",feature + " are playing into current " + target + " Rate" " :  ",(1-p)*100,"%")
            else :
                if HT ==1:
                    print(STT," .",target + " are not playing into current " + feature + " Rate" " :  ",(1-p)*100,"%")
                else:
                    print(STT," .",feature + " are not playing into current " + target + " Rate" " :  ",(1-p)*100,"%")

# %%
# Dùng Correlation để xử lý target là number và feature là number 
def Xuly_Correlation(Data,feature,target,STT):
    # lấy random 50 data của feature và của target
    
    sample_feature=random.sample(list(Data[feature]),k=50)
    sample_target=random.sample(list(Data[target]),k=50)
    r,p=stats.pearsonr(sample_feature, sample_target)
    #print(r,p)
    if abs(r) >= 0.5 :
        print(STT," .",feature + " are playing into current " + target + " Rate" " with r = ",r)  
    else:
        print(STT," .",feature + " are not playing into current " + target + " Rate" " with r = ",r)

# %%
# input data type file.csv
Data=pd.read_csv("Data.csv")
#print(Data.shape)
#print(Data.head(1))
def main_(Data,target):
    target_type=number_or_category(Data[target][0])
    #print("Target có dạng ",target_type)
    STT=0
    for col in range(Data.shape[1]):
        if Data.columns[col] !=target:
            feature=Data.columns[col]
            feature_type=number_or_category(Data.iloc[0][col])
            #print(feature_type)
            if target_type=="number" and feature_type == "number":
                Xuly_Correlation(Data,feature,target,STT)
            if target_type=="number" and feature_type == "category":
                Xuly_T_test(Data,feature,target,STT,0)
            if target_type=="category" and feature_type == "number":
                #Reverve H0
                Xuly_T_test(Data,target,feature,STT,1)
            if target_type=="category" and feature_type == "category":
                # convert  target to binary
                #thuộc tính đầu tiên của target đưa về 0 còn lại đưa về 1(với attrition có 2 thuộc tính là yes và no)
                #nếu chỉ có 1 thuộc tính thì đều chuyển =0  > sẽ không ảnh hưởng và p=nan %
                target_set=list(set(Data[target]))
                thuoc_tinh0=target_set[0]
                # lấy row có thuộc tính ==thuoc_tinh0
                row=list(Data[Data[target]==thuoc_tinh0].index)
                #print(row)
                Data_binary=Data
                #print(Data_binary)
                #chuyển tất cả các data của target =1
                Data_binary[target]=1
                #chuyển các data của target có thuoc_tinh0=0
                for r in row:
                    Data_binary[target].loc[r]=0
                #print(Data_binary)
                # target có dạng number và feature có dang category
                Xuly_T_test(Data_binary,feature,target,STT,0)
        STT+=1

# %%
print("What are key factors that are playing into current attrition Rate ?")      
main_(Data,"Attrition")    
print("What are key factors that are playing into current JobSatisfaction rates ?")
main_(Data,"JobSatisfaction")
print("What are key factors that are playing into current EnvironmentSatisfaction rates ?")
main_(Data,"EnvironmentSatisfaction")
print("What are key factors that are playing into current RelationshipSatisfaction rates ?")
main_(Data,"RelationshipSatisfaction")
# Out:
# What are key factors that are playing into current attrition Rate ?
# 0  . Age are playing into current Attrition Rate :   97.14521679782175 %
# 2  . BusinessTravel are playing into current Attrition Rate :   99.66020673735603 %
# 3  . DailyRate are not playing into current Attrition Rate :   28.328299566833703 %
# 4  . Department are not playing into current Attrition Rate :   47.05851289570154 %
# 5  . DistanceFromHome are not playing into current Attrition Rate :   90.96266205273629 %
# 6  . Education are not playing into current Attrition Rate :   51.5713402633138 %
# 7  . Data of  EducationField not enough 32 for one properties
# 8  . EmployeeCount are not playing into current Attrition Rate :   nan %
# 9  . EmployeeNumber are not playing into current Attrition Rate :   8.826736884355736 %
# 10  . EnvironmentSatisfaction are not playing into current Attrition Rate :   72.03615110994437 %
# 11  . Gender are not playing into current Attrition Rate :   27.56601526954652 %
# 12  . HourlyRate are not playing into current Attrition Rate :   42.71214094435523 %
# 13  . JobInvolvement are not playing into current Attrition Rate :   76.69415982605665 %
# 14  . JobLevel are playing into current Attrition Rate :   97.2749278611975 %
# 15  . JobRole are playing into current Attrition Rate :   99.54727317481036 %
# 16  . JobSatisfaction are not playing into current Attrition Rate :   93.68239968712868 %
# 17  . MaritalStatus are not playing into current Attrition Rate :   87.58363165270627 %
# 18  . MonthlyIncome are playing into current Attrition Rate :   99.36855541903397 %
# 19  . MonthlyRate are not playing into current Attrition Rate :   78.54532363015399 %
# 20  . NumCompaniesWorked are not playing into current Attrition Rate :   14.461854336705871 %
# 21  . Over18 are not playing into current Attrition Rate
# 22  . OverTime are playing into current Attrition Rate :   98.66466544907074 %
# 23  . PercentSalaryHike are not playing into current Attrition Rate :   44.59693089639865 %
# 24  . PerformanceRating are not playing into current Attrition Rate :   0.0 %
# 25  . RelationshipSatisfaction are not playing into current Attrition Rate :   76.13224685247546 %
# 26  . StandardHours are not playing into current Attrition Rate :   nan %
# 27  . StockOptionLevel are not playing into current Attrition Rate :   10.802793824747592 %
# 28  . TotalWorkingYears are not playing into current Attrition Rate :   93.99491929466897 %
# 29  . TrainingTimesLastYear are not playing into current Attrition Rate :   6.922242009857548 %
# 30  . WorkLifeBalance are not playing into current Attrition Rate :   24.67238165701281 %
# 31  . YearsAtCompany are not playing into current Attrition Rate :   89.83731438110644 %
# 32  . YearsInCurrentRole are playing into current Attrition Rate :   99.21500884383502 %
# 33  . YearsSinceLastPromotion are not playing into current Attrition Rate :   17.825428534143594 %
# 34  . YearsWithCurrManager are not playing into current Attrition Rate :   74.3595336413851 %
# What are key factors that are playing into current JobSatisfaction rates ?
# 0  . Age are not playing into current JobSatisfaction Rate with r =  -0.11142173658163375
# 1  . Attrition are not playing into current JobSatisfaction Rate with r =  0.0658627012888193
# 2  . BusinessTravel are not playing into current JobSatisfaction Rate :   31.273401801969737 %
# 3  . DailyRate are not playing into current JobSatisfaction Rate with r =  -0.0043391730941324674
# 4  . Department are not playing into current JobSatisfaction Rate :   66.74623472886906 %
# 5  . DistanceFromHome are not playing into current JobSatisfaction Rate with r =  -0.08198706796700596
# 6  . Education are not playing into current JobSatisfaction Rate with r =  -0.030083407105938875
# 7  . Data of  EducationField not enough 32 for one properties
# 8  . EmployeeCount are not playing into current JobSatisfaction Rate with r =  nan
# 9  . EmployeeNumber are not playing into current JobSatisfaction Rate with r =  -0.060386238579416204
# 10  . EnvironmentSatisfaction are not playing into current JobSatisfaction Rate with r =  0.045060726252083905
# 11  . Gender are not playing into current JobSatisfaction Rate :   62.41120050777133 %
# 12  . HourlyRate are not playing into current JobSatisfaction Rate with r =  0.14491152786568218
# 13  . JobInvolvement are not playing into current JobSatisfaction Rate with r =  0.04213620552862918
# 14  . JobLevel are not playing into current JobSatisfaction Rate with r =  -0.10400827973245591
# 15  . JobRole are not playing into current JobSatisfaction Rate :   25.30978751723243 %
# 17  . MaritalStatus are not playing into current JobSatisfaction Rate :   25.27307267649079 %
# 18  . MonthlyIncome are not playing into current JobSatisfaction Rate with r =  0.046948013970900926
# 19  . MonthlyRate are not playing into current JobSatisfaction Rate with r =  -0.14853604080184402
# 20  . NumCompaniesWorked are not playing into current JobSatisfaction Rate with r =  0.20463161048697143
# 21  . Over18 are not playing into current JobSatisfaction Rate
# 22  . OverTime are not playing into current JobSatisfaction Rate :   58.46499217275871 %
# 23  . PercentSalaryHike are not playing into current JobSatisfaction Rate with r =  -0.24327852138420392
# 24  . PerformanceRating are not playing into current JobSatisfaction Rate with r =  -0.04107102606068634
# 25  . RelationshipSatisfaction are not playing into current JobSatisfaction Rate with r =  -0.1773066952656725
# 26  . StandardHours are not playing into current JobSatisfaction Rate with r =  nan
# 27  . StockOptionLevel are not playing into current JobSatisfaction Rate with r =  0.06761900360008916
# 28  . TotalWorkingYears are not playing into current JobSatisfaction Rate with r =  0.009160230124155136
# 29  . TrainingTimesLastYear are not playing into current JobSatisfaction Rate with r =  0.05475893865041433
# 30  . WorkLifeBalance are not playing into current JobSatisfaction Rate with r =  -0.009182285451566852
# 31  . YearsAtCompany are not playing into current JobSatisfaction Rate with r =  0.09354159213365433
# 32  . YearsInCurrentRole are not playing into current JobSatisfaction Rate with r =  -0.07782577043930351
# 33  . YearsSinceLastPromotion are not playing into current JobSatisfaction Rate with r =  -0.16811783295460098
# 34  . YearsWithCurrManager are not playing into current JobSatisfaction Rate with r =  -0.05026054749164445
# What are key factors that are playing into current EnvironmentSatisfaction rates ?
# 0  . Age are not playing into current EnvironmentSatisfaction Rate with r =  0.007951919943309061
# 1  . Attrition are not playing into current EnvironmentSatisfaction Rate with r =  0.2096034298589439
# 2  . BusinessTravel are not playing into current EnvironmentSatisfaction Rate :   71.94447242548945 %
# 3  . DailyRate are not playing into current EnvironmentSatisfaction Rate with r =  0.040340394299424834
# 4  . Department are not playing into current EnvironmentSatisfaction Rate :   45.93960196115043 %
# 5  . DistanceFromHome are not playing into current EnvironmentSatisfaction Rate with r =  0.04819311686249828
# 6  . Education are not playing into current EnvironmentSatisfaction Rate with r =  0.10450150448017767
# 7  . Data of  EducationField not enough 32 for one properties
# 8  . EmployeeCount are not playing into current EnvironmentSatisfaction Rate with r =  nan
# 9  . EmployeeNumber are not playing into current EnvironmentSatisfaction Rate with r =  -0.04934830021578138
# 11  . Gender are not playing into current EnvironmentSatisfaction Rate :   41.10268541490392 %
# 12  . HourlyRate are not playing into current EnvironmentSatisfaction Rate with r =  -0.05060821103556723
# 13  . JobInvolvement are not playing into current EnvironmentSatisfaction Rate with r =  -0.03949605346335146
# 14  . JobLevel are not playing into current EnvironmentSatisfaction Rate with r =  -0.08565038814321096
# 15  . JobRole are not playing into current EnvironmentSatisfaction Rate :   71.72057201143059 %
# 16  . JobSatisfaction are not playing into current EnvironmentSatisfaction Rate with r =  -0.1285946097067952
# 17  . MaritalStatus are not playing into current EnvironmentSatisfaction Rate :   76.66715748042559 %
# 18  . MonthlyIncome are not playing into current EnvironmentSatisfaction Rate with r =  0.22570267606290956
# 19  . MonthlyRate are not playing into current EnvironmentSatisfaction Rate with r =  0.05386705651634585
# 20  . NumCompaniesWorked are not playing into current EnvironmentSatisfaction Rate with r =  0.19304587639455084
# 21  . Over18 are not playing into current EnvironmentSatisfaction Rate
# 22  . OverTime are playing into current EnvironmentSatisfaction Rate :   99.93607823092803 %
# 23  . PercentSalaryHike are not playing into current EnvironmentSatisfaction Rate with r =  -0.2123225363679475
# 24  . PerformanceRating are not playing into current EnvironmentSatisfaction Rate with r =  0.15430334996209194
# 25  . RelationshipSatisfaction are not playing into current EnvironmentSatisfaction Rate with r =  -0.03830770884410034
# 26  . StandardHours are not playing into current EnvironmentSatisfaction Rate with r =  nan
# 27  . StockOptionLevel are not playing into current EnvironmentSatisfaction Rate with r =  0.1456965678848391
# 28  . TotalWorkingYears are not playing into current EnvironmentSatisfaction Rate with r =  0.1999954386473629
# 29  . TrainingTimesLastYear are not playing into current EnvironmentSatisfaction Rate with r =  0.06439025471412327
# 30  . WorkLifeBalance are not playing into current EnvironmentSatisfaction Rate with r =  0.1335089164331223
# 31  . YearsAtCompany are not playing into current EnvironmentSatisfaction Rate with r =  0.008788206380342244
# 32  . YearsInCurrentRole are not playing into current EnvironmentSatisfaction Rate with r =  0.02919754514250565
# 33  . YearsSinceLastPromotion are not playing into current EnvironmentSatisfaction Rate with r =  -0.09295386489162576
# 34  . YearsWithCurrManager are not playing into current EnvironmentSatisfaction Rate with r =  0.28202356544669754
# What are key factors that are playing into current RelationshipSatisfaction rates ?
# 0  . Age are not playing into current RelationshipSatisfaction Rate with r =  0.19106745228606659
# 1  . Attrition are not playing into current RelationshipSatisfaction Rate with r =  0.22007454762625683
# 2  . BusinessTravel are not playing into current RelationshipSatisfaction Rate :   65.58636034517106 %
# 3  . DailyRate are not playing into current RelationshipSatisfaction Rate with r =  -0.22669503183158063
# 4  . Department are playing into current RelationshipSatisfaction Rate :   96.17971904769915 %
# 5  . DistanceFromHome are not playing into current RelationshipSatisfaction Rate with r =  0.018848199754439188
# 6  . Education are not playing into current RelationshipSatisfaction Rate with r =  -0.0007627032892467203
# 7  . Data of  EducationField not enough 32 for one properties
# 8  . EmployeeCount are not playing into current RelationshipSatisfaction Rate with r =  nan
# 9  . EmployeeNumber are not playing into current RelationshipSatisfaction Rate with r =  0.04918556842507742
# 10  . EnvironmentSatisfaction are not playing into current RelationshipSatisfaction Rate with r =  0.11829687096260637
# 11  . Gender are not playing into current RelationshipSatisfaction Rate :   70.33179784186461 %
# 12  . HourlyRate are not playing into current RelationshipSatisfaction Rate with r =  0.0910832598184884
# 13  . JobInvolvement are not playing into current RelationshipSatisfaction Rate with r =  -0.08882384629675891
# 14  . JobLevel are not playing into current RelationshipSatisfaction Rate with r =  -0.20645809772588483
# 15  . JobRole are not playing into current RelationshipSatisfaction Rate :   58.671417705271686 %
# 16  . JobSatisfaction are not playing into current RelationshipSatisfaction Rate with r =  -0.02003188877742068
# 17  . MaritalStatus are not playing into current RelationshipSatisfaction Rate :   8.141426801564222 %
# 18  . MonthlyIncome are not playing into current RelationshipSatisfaction Rate with r =  -0.007294517117399063
# 19  . MonthlyRate are not playing into current RelationshipSatisfaction Rate with r =  -0.0826073503751823
# 20  . NumCompaniesWorked are not playing into current RelationshipSatisfaction Rate with r =  -0.018382306354372924
# 21  . Over18 are not playing into current RelationshipSatisfaction Rate
# 22  . OverTime are not playing into current RelationshipSatisfaction Rate :   57.15399039158401 %
# 23  . PercentSalaryHike are not playing into current RelationshipSatisfaction Rate with r =  0.08768398056869875
# 24  . PerformanceRating are not playing into current RelationshipSatisfaction Rate with r =  0.1276301395872591
# 26  . StandardHours are not playing into current RelationshipSatisfaction Rate with r =  nan
# 27  . StockOptionLevel are not playing into current RelationshipSatisfaction Rate with r =  0.1726131860089292
# 28  . TotalWorkingYears are not playing into current RelationshipSatisfaction Rate with r =  -0.1751922165780633
# 29  . TrainingTimesLastYear are not playing into current RelationshipSatisfaction Rate with r =  -0.13617178431642535
# 30  . WorkLifeBalance are not playing into current RelationshipSatisfaction Rate with r =  0.05291948411217953
# 31  . YearsAtCompany are not playing into current RelationshipSatisfaction Rate with r =  0.15978332442335236
# 32  . YearsInCurrentRole are not playing into current RelationshipSatisfaction Rate with r =  -0.13586053156466332
# 33  . YearsSinceLastPromotion are not playing into current RelationshipSatisfaction Rate with r =  0.003149313426096173
# 34  . YearsWithCurrManager are not playing into current RelationshipSatisfaction Rate with r =  0.12191844216862957
